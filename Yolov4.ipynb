# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.7-py2.py3-none-any.whl size=13945 sha256=8d31587974f0510e9955e4cc0d3606c02179b15be619211aca7de2d09326e61a
#   Stored in directory: /root/.cache/pip/wheels/81/20/7e/1dd0daad1575d5260916bb1e9781246430647adaef4b3ca3b3
# Successfully built pytesseract
# ...

# %%
#Detect img
# !python /content/gdrive/MyDrive/Yolov4/detect.py --weights /content/gdrive/MyDrive/Yolov4/checkpoints/yolov4-416 --size 416 --model yolov4 --images /content/gdrive/MyDrive/Yolov4/data/images/kite.jpg --output /content/gdrive/MyDrive/Yolov4/detections/kite.jpg

# %%
#Detect img
# !python /content/gdrive/MyDrive/Yolov4/detect_v1.py

# %%
# !python /content/gdrive/MyDrive/Yolov4/detect_v2.py

# %%
# !python /content/gdrive/MyDrive/Yolov4/detect_v3.py

# %%
# !python /content/gdrive/MyDrive/Yolov4/detect_v4.py

# %%
from IPython.display import Image
PATH = '/content/gdrive/MyDrive/Yolov4/'
Image(PATH+'detections/detection6.png', width=800, height=600)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
